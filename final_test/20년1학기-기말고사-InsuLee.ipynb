# %% [markdown]
# # 2020년 1학기 기말시험

# %% [markdown]
# # 이름 : your name here(더블 클릭)

# %% [markdown]
# https://colab.research.google.com/에 import하여 셀에 답을 적고 RUN하십시오. 출력한 결과에 따라 스코어링됩니다.

# %% [markdown]
# Q1. CNN 신경망에서 2D 컨볼루션 레이어를 거친 행렬의 값을 파이썬 array형태로 적으시오. 계산을 위해 계산기앱 또는 액셀을 사용해도 좋습니다.

# %%
""" 문제
x = [[1,2,3],
     [4,5,6],
     [7,8,9]]
     
kernel W =[[0,1],
          [1,0]]

Padding = VALID

convolution을 한 결과를 행렬 y로 하여 print(y)로 출력하시오.
"""
y=   [[6, 8],
      [12, 14]]# 여러분의 answer를 파이썬 어레이로 적고 Run하시오.
print(y)
# Out:
# [[6, 8], [12, 14]]

# %% [markdown]
# Q2, 아래의 Confusion Matrix를 보고 질문에 답하시오

# %%
# 문제 : 아래의 혼동행렬을 보고 TPR과 FNR을 계산하시오. 단 계산하는 공식을 파이썬으로 코딩하여 값을 구하시오.
# 혼동행렬의 row는 실제값, column은 예측값, (1,1)이 True & Positive
# 정의 : TPR = True Postive rate, FNR = False Negative rate
import seaborn as sn
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

array = np.array([[850,6],
                  [50,94]])         

sn.set(font_scale=2.0) # for label size
sn.heatmap(array, annot=True, annot_kws={"size": 18}, fmt='d') # font size

plt.show()
# Out:
# /usr/local/lib/python3.6/dist-packages/statsmodels/tools/_testing.py:19: FutureWarning: pandas.util.testing is deprecated. Use the functions in the public API at pandas.testing instead.
#   import pandas.util.testing as tm

# %%
# Q2.1 TPR=?  아래에 계산식을 쓰고 Run 시키시오
# 여러분의 코드 
array = np.array(array)
tpr=array[0,0]/(array[0,0]+array[0,1])
print('TPR값은 ', tpr)
# Out:
# TPR값은  0.9929906542056075

# %%
# Q2.2 FNR 계산을 위한 코드를 쓰고  Run하시오
# 여러분의 코드
fnr=array[0,1]/(array[0,1]+array[0,0])
print('FNR값은 ', fnr)
# Out:
# FNR값은  0.007009345794392523

# %%
#  Q2.3 accurary 계산을 위한 코드를 쓰고  Run하시오
# 여러분의 코드
accuracy=(array[0,1]+array[0,0])/(array[0,0]+array[0,1]+array[1,0]+array[1,1])
print('Accurary값은 ', accuracy)
# Out:
# Accurary값은  0.856

# %% [markdown]
# Q3. 다음 신경망 다이어그램을 보고 이를 구현하기 위한 파이썬 코드를 완성하시오

# %%
! wget --no-check-certificate 'https://docs.google.com/uc?export=download&id=1jGQthuWngRlgUq7masWosTq1LyzwUAS7' -O 퍼셉트론.png
from IPython.display import Image
Image("퍼셉트론.png", width=500)
# Out:
# --2020-06-10 04:30:58--  https://docs.google.com/uc?export=download&id=1jGQthuWngRlgUq7masWosTq1LyzwUAS7
# Resolving docs.google.com (docs.google.com)... 74.125.142.113, 74.125.142.100, 74.125.142.102, ...
# Connecting to docs.google.com (docs.google.com)|74.125.142.113|:443... connected.
# HTTP request sent, awaiting response... 302 Moved Temporarily
# Location: https://doc-0s-1s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/v5ku50ngfd7o031refco5bo68nhmnfbj/1591763400000/04591858293269658552/*/1jGQthuWngRlgUq7masWosTq1LyzwUAS7?e=download [following]
# Warning: wildcards not supported in HTTP.
# --2020-06-10 04:30:59--  https://doc-0s-1s-docs.googleusercontent.com/docs/securesc/ha0ro937gcuc7l7deffksulhg5h7mbp1/v5ku50ngfd7o031refco5bo68nhmnfbj/1591763400000/04591858293269658552/*/1jGQthuWngRlgUq7masWosTq1LyzwUAS7?e=download
# Resolving doc-0s-1s-docs.googleusercontent.com (doc-0s-1s-docs.googleusercontent.com)... 74.125.195.132, 2607:f8b0:400e:c09::84
# Connecting to doc-0s-1s-docs.googleusercontent.com (doc-0s-1s-docs.googleusercontent.com)|74.125.195.132|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 18076 (18K) [image/png]
# Saving to: ‘퍼셉트론.png’
#
# 퍼셉트론.png        100%[===================>]  17.65K  --.-KB/s    in 0s
#
# 2020-06-10 04:30:59 (97.7 MB/s) - ‘퍼셉트론.png’ saved [18076/18076]

# %%
#Q3. 위의 그림에 맞는 신경망을 코드로 설계하시오.
"""
n = 4 # ?을 채우시오
n_inputs = 4  # ?을 채우시오
n_hidden = 4 # ?을 채우시오 
n_outputs = 2 # ?을 채우시오  
X=tf.placeholder(tf.float64, shape=(None, 784), name='X') # ?을 채우시오
with tf.name_scope('nn'):
hidden1 = make_nn_layer('hidden', ?, ?, activation=tf.nn.relu) # ?을 채우시오
outputs = make_nn_layer('outputs', ?, ?) # ?을 채우시오
"""

# %% [markdown]
# Q4. 아래의 표를 보고 Keras 코드를 완성하시오

# %%
#Q4 표
"""
Layer (type)                 Output Shape              Param #   
=================================================================
conv2d_6 (Conv2D)            (None, 24, 24, 32)        832       
_________________________________________________________________
max_pooling2d_5 (MaxPooling2 (None, 12, 12, 32)        0         
_________________________________________________________________
dropout_6 (Dropout)          (None, 12, 12, 32)        0         
_________________________________________________________________
conv2d_7 (Conv2D)            (None, 10, 10, 64)        18496     
_________________________________________________________________
max_pooling2d_6 (MaxPooling2 (None, 5, 5, 64)          0         
_________________________________________________________________
dropout_7 (Dropout)          (None, 5, 5, 64)          0         
_________________________________________________________________
conv2d_8 (Conv2D)            (None, 5, 5, 128)         8320      
_________________________________________________________________
max_pooling2d_7 (MaxPooling2 (None, 2, 2, 128)         0         
_________________________________________________________________
dropout_8 (Dropout)          (None, 2, 2, 128)         0         
_________________________________________________________________
flatten_3 (Flatten)          (None, 512)               0         
_________________________________________________________________
dense_5 (Dense)              (None, 128)               65664     
_________________________________________________________________
dense_6 (Dense)              (None, 10)                1290      
=================================================================

"""
# Out:
# '\nLayer (type)                 Output Shape              Param #   \n=================================================================\nconv2d_6 (Conv2D)            (None, 24, 24, 32)        832       \n_________________________________________________________________\nmax_pooling2d_5 (MaxPooling2 (None, 12, 12, 32)        0         \n_________________________________________________________________\ndropout_6 (Dropout)          (None, 12, 12, 32)        0         \n_________________________________________________________________\nconv2d_7 (Conv2D)            (None, 10, 10, 64)        18496     \n_________________________________________________________________\nmax_pooling2d_6 (MaxPooling2 (None, 5, 5, 64)          0         \n_________________________________________________________________\ndropout_7 (Dropout)          (None, 5, 5, 64)          0         \n_________________________________________________________________\nconv2d_8 (Conv2D)            (None, 5, 5, 128)         8320      \n_________________________________________________________________\nmax_pooling2d_7 (MaxPooling2 (None, 2, 2, 128)         0         \n_________________________________________________________________\ndropout_8 (Dropout)          (None, 2, 2, 128)         0         \n_________________________________________________________________\nflatten_3 (Flatten)          (None, 512)               0         \n_________________________________________________________________\ndense_5 (Dense)              (None, 128)               65664     \n_________________________________________________________________\ndense_6 (Dense)              (None, 10)                1290      \n=================================================================\n\n'

# %%
# Q4. 이곳에 위의 표에 맞는 딥러닝의 모델을 Keras로 코딩하십시오. 모델 부문만 작성하고 마지막에 print로 summary를 출력하십시오.
# 가정 1 : input은 24 x 24의 흑백 이미지
# 가정 2 : convolution layer에서 사용하는 activation function은 ReLU로 통일 
# 가정 3 : maxpooling 시 pool_size는 2 x 2
# 가정 4 : dropout rate는 0.5
# 가정 5 : dense_5 layer에서 사용하는 activation function은 ReLU
# 가정 6 : dense_6 layer에서 사용하는 activation function은 softmax
import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout, Flatten
from keras.layers import Conv2D, MaxPooling2D
from keras import backend as K

mymodel = Sequential()


"""
your code here
"""
from keras.layers import Activation
mymodel.add(Conv2D(32, kernel_size=(3, 3),activation='linear',padding='same',input_shape=(24,24,1)))


mymodel.add(Activation('relu'))
mymodel.add(MaxPooling2D((2, 2),padding='same'))
mymodel.add(Dropout(0.5))
mymodel.add(Conv2D(64, (3, 3), activation='linear',padding='valid'))

mymodel.add(Activation('relu'))
mymodel.add(MaxPooling2D(pool_size=(2, 2),padding='same'))
mymodel.add(Dropout(0.5))
mymodel.add(Conv2D(128, (3, 3), activation='linear',padding='same'))

mymodel.add(Activation('relu'))
mymodel.add(MaxPooling2D(pool_size=(2, 2),padding='valid'))
mymodel.add(Dropout(0.5))
mymodel.add(Flatten())
mymodel.add(Dense(128, activation='linear'))

mymodel.add(Activation('relu'))
mymodel.add(Dropout(0.5))
mymodel.add(Dense(10, activation='softmax'))


print(mymodel.summary())
# The End
# Out:
# Model: "sequential_13"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_32 (Conv2D)           (None, 24, 24, 32)        320
# _________________________________________________________________
# activation_35 (Activation)   (None, 24, 24, 32)        0
# _________________________________________________________________
# max_pooling2d_31 (MaxPooling (None, 12, 12, 32)        0
# _________________________________________________________________
# dropout_35 (Dropout)         (None, 12, 12, 32)        0
# _________________________________________________________________
# conv2d_33 (Conv2D)           (None, 10, 10, 64)        18496
# _________________________________________________________________
# activation_36 (Activation)   (None, 10, 10, 64)        0
# _________________________________________________________________
# max_pooling2d_32 (MaxPooling (None, 5, 5, 64)          0
# _________________________________________________________________
# dropout_36 (Dropout)         (None, 5, 5, 64)          0
# _________________________________________________________________
# conv2d_34 (Conv2D)           (None, 5, 5, 128)         73856
# _________________________________________________________________
# activation_37 (Activation)   (None, 5, 5, 128)         0
# _________________________________________________________________
# max_pooling2d_33 (MaxPooling (None, 2, 2, 128)         0
# _________________________________________________________________
# dropout_37 (Dropout)         (None, 2, 2, 128)         0
# _________________________________________________________________
# flatten_6 (Flatten)          (None, 512)               0
# _________________________________________________________________
# dense_9 (Dense)              (None, 128)               65664
# _________________________________________________________________
# activation_38 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_38 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_10 (Dense)             (None, 10)                1290
# =================================================================
# Total params: 159,626
# Trainable params: 159,626
# Non-trainable params: 0
# _________________________________________________________________
# None

# %% [markdown]
# Q5. 아래  코드가 출력하는 그래프에서 validation loss 값이 모든 epoch 구간에서 training loss 값보다 작도록  코드를 수정하시오. 현재의 그래프는 최적 상태가 아닙니다.

# %%
from keras.datasets import mnist
from matplotlib import pyplot as plt
plt.style.use('dark_background')
from keras.models import Sequential
from keras.layers import Dense, Flatten, Activation, Dropout
from keras.utils import normalize, to_categorical

(X_train, y_train), (X_test, y_test) = mnist.load_data()

plt.imshow(X_train[0], cmap = plt.cm.binary)
plt.show()

X_train = normalize(X_train, axis=1)
X_test = normalize(X_test, axis=1)
y_train = to_categorical(y_train)
y_test = to_categorical(y_test)

model = Sequential()
model.add(Flatten(input_shape=(28, 28)))
model.add(Dropout(0.25))
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(128))
model.add(Activation('relu'))
model.add(Dropout(0.25))
model.add(Dense(10))
model.add(Activation('softmax'))
model.summary()

model.compile(
    loss='categorical_crossentropy',
    optimizer='adam',
    metrics=['accuracy']
)
history = model.fit(
    X_train,
    y_train,
    epochs=10,
    batch_size=32,
    validation_split=0.1,
    verbose = 1,
    shuffle=True
)

loss = history.history['loss']
val_loss = history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Model: "sequential_18"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_10 (Flatten)         (None, 784)               0
# _________________________________________________________________
# dropout_41 (Dropout)         (None, 784)               0
# _________________________________________________________________
# dense_22 (Dense)             (None, 128)               100480
# _________________________________________________________________
# activation_48 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_42 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_23 (Dense)             (None, 128)               16512
# _________________________________________________________________
# activation_49 (Activation)   (None, 128)               0
# _________________________________________________________________
# dropout_43 (Dropout)         (None, 128)               0
# _________________________________________________________________
# dense_24 (Dense)             (None, 10)                1290
# _________________________________________________________________
# activation_50 (Activation)   (None, 10)                0
# =================================================================
# Total params: 118,282
# Trainable params: 118,282
# Non-trainable params: 0
# _________________________________________________________________
# Train on 54000 samples, validate on 6000 samples
# Epoch 1/10
# 54000/54000 [==============================] - 6s 115us/step - loss: 0.4387 - accuracy: 0.8656 - val_loss: 0.1389 - val_accuracy: 0.9570
# Epoch 2/10
# 54000/54000 [==============================] - 6s 114us/step - loss: 0.2272 - accuracy: 0.9301 - val_loss: 0.1029 - val_accuracy: 0.9678
# Epoch 3/10
# 54000/54000 [==============================] - 6s 116us/step - loss: 0.1822 - accuracy: 0.9442 - val_loss: 0.0863 - val_accuracy: 0.9743
# Epoch 4/10
# 54000/54000 [==============================] - 6s 117us/step - loss: 0.1605 - accuracy: 0.9506 - val_loss: 0.0824 - val_accuracy: 0.9760
# Epoch 5/10
# 54000/54000 [==============================] - 6s 117us/step - loss: 0.1445 - accuracy: 0.9543 - val_loss: 0.0741 - val_accuracy: 0.9785
# Epoch 6/10
# 54000/54000 [==============================] - 6s 115us/step - loss: 0.1362 - accuracy: 0.9572 - val_loss: 0.0770 - val_accuracy: 0.9773
# Epoch 7/10
# 54000/54000 [==============================] - 6s 116us/step - loss: 0.1259 - accuracy: 0.9601 - val_loss: 0.0725 - val_accuracy: 0.9792
# Epoch 8/10
# 54000/54000 [==============================] - 6s 120us/step - loss: 0.1234 - accuracy: 0.9617 - val_loss: 0.0666 - val_accuracy: 0.9793
# Epoch 9/10
# 54000/54000 [==============================] - 7s 120us/step - loss: 0.1150 - accuracy: 0.9633 - val_loss: 0.0662 - val_accuracy: 0.9810
# Epoch 10/10
# 54000/54000 [==============================] - 7s 121us/step - loss: 0.1109 - accuracy: 0.9655 - val_loss: 0.0640 - val_accuracy: 0.9817

# %% [markdown]
# Q6. Mini-batch size & Learning Rate 튜닝

# %%
# mlp for the blobs problem with minibatch gradient descent with varied batch size
# 아래의 코드에서 다음 두 개의 파라미터를 조합하여 최고의 모델링 성능을 내고 그 결과를 print()로 출력하십시오.
# 튜닝할 파라미터 : batch_size & lr (각각 3가지의 옵션이 있으므로 두 파라미터를 조합할 수 있는 경우의 수는 모두 9가지)
# 모델의 성능 평가 기준은 다음의 우선순위에 따라 결정하시오. 
# 1. Validation Loss가 최소, 2. Accuracy는 최고값에 가까울 것
# 9번의 실험 후 최적이라고 생각되는 파라미터 값을 코드에 지정하고 셀을 다시 run하여 최종 결과를 출력하시오.
# %%time
from sklearn.datasets import make_blobs
from keras.layers import Dense
from keras.models import Sequential
from keras.optimizers import SGD
from keras.utils import to_categorical
from matplotlib import pyplot

# prepare train and test dataset
def prepare_data():
	# generate 2d classification dataset
	X, y = make_blobs(n_samples=1000, centers=3, n_features=2, cluster_std=2, random_state=2)
	# one hot encode output variable
	y = to_categorical(y)
	# split into train and test
	n_train = 500
	trainX, testX = X[:n_train, :], X[n_train:, :]
	trainy, testy = y[:n_train], y[n_train:]
	return trainX, trainy, testX, testy

# fit a model and plot learning curve
def fit_model(trainX, trainy, testX, testy, n_batch):
	
  # define model
	model = Sequential()
	model.add(Dense(50, input_dim=2, activation='relu', kernel_initializer='he_uniform'))
	model.add(Dense(3, activation='softmax'))
	
  # lr의 값을  0.1, 0.01, 0.001 중에서 선택하여 이곳에 지정
	your_lr = 0.01
	opt = SGD(lr=your_lr, momentum=0.9) 
	model.compile(loss='categorical_crossentropy', optimizer=opt, metrics=['accuracy'])
	# fit model
	history = model.fit(trainX, trainy, validation_data=(testX, testy), epochs=150, verbose=2, batch_size=n_batch)
	print('accuracy = ', format(history.history['accuracy'][149],".3f"), ' ', 'validation loss = ', format(history.history['val_loss'][149],".3f"))
  # plot learning curves
	pyplot.plot(history.history['accuracy'], label='train')
	pyplot.plot(history.history['val_loss'], label='test')
	pyplot.title('batch='+str(n_batch), pad=-40)



# prepare dataset
trainX, trainy, testX, testy = prepare_data()

# batch_size의 값을   16, 32, 64 중에서 선택하여 이곳에 지정
your_batch_size = 32
batch_size = your_batch_size

fit_model(trainX, trainy, testX, testy, batch_size)
# show learning curves
pyplot.show()

# 결과를 메모장에 적어놓고 lr과 batch_size를 바꿔가며 최적의 파라미터를 찾아가시오.
# 최적의 lr과 batch_size를 선택하여 위의 코드에 적고 Run한 결과룰 출력하여 제출하시오. 

"""
0.1 16
accuracy =  0.706   validation loss =  0.768
0.01 16
accuracy =  0.822   validation loss =  0.441
0.001 16
accuracy =  0.808   validation loss =  0.428
0.1 32
accuracy =  0.838   validation loss =  0.489
0.01 32
accuracy =  0.828   validation loss =  0.424
0.001 32
accuracy =  0.806   validation loss =  0.427
0.1 64
accuracy =  0.832   validation loss =  0.482
0.01 64
accuracy =  0.808   validation loss =  0.460
0.001 64
accuracy =  0.784   validation loss =  0.492
"""
# Out:
# Train on 500 samples, validate on 500 samples
# Epoch 1/150
#  - 0s - loss: 2.9134 - accuracy: 0.4960 - val_loss: 2.7039 - val_accuracy: 0.5280
# Epoch 2/150
#  - 0s - loss: 3.0182 - accuracy: 0.5260 - val_loss: 1.6003 - val_accuracy: 0.6560
# Epoch 3/150
#  - 0s - loss: 1.4798 - accuracy: 0.6500 - val_loss: 1.7404 - val_accuracy: 0.5300
# Epoch 4/150
#  - 0s - loss: 1.3589 - accuracy: 0.6040 - val_loss: 0.9263 - val_accuracy: 0.6420
# Epoch 5/150
#  - 0s - loss: 0.7971 - accuracy: 0.6860 - val_loss: 0.5540 - val_accuracy: 0.7580
# Epoch 6/150
#  - 0s - loss: 0.7007 - accuracy: 0.6960 - val_loss: 0.5915 - val_accuracy: 0.7460
# Epoch 7/150
#  - 0s - loss: 0.6281 - accuracy: 0.7420 - val_loss: 0.5250 - val_accuracy: 0.7660
# Epoch 8/150
#  - 0s - loss: 0.5330 - accuracy: 0.7680 - val_loss: 0.5498 - val_accuracy: 0.7680
# Epoch 9/150
#  - 0s - loss: 0.5292 - accuracy: 0.7460 - val_loss: 0.4717 - val_accuracy: 0.8380
# Epoch 10/150
#  - 0s - loss: 0.5029 - accuracy: 0.7760 - val_loss: 0.4752 - val_accuracy: 0.8080
# Epoch 11/150
#  - 0s - loss: 0.4901 - accuracy: 0.7880 - val_loss: 0.4538 - val_accuracy: 0.8200
# Epoch 12/150
#  - 0s - loss: 0.5211 - accuracy: 0.7760 - val_loss: 0.4443 - val_accuracy: 0.8120
# Epoch 13/150
#  - 0s - loss: 0.4824 - accuracy: 0.7840 - val_loss: 0.4514 - val_accuracy: 0.8080
# Epoch 14/150
#  - 0s - loss: 0.4745 - accuracy: 0.7940 - val_loss: 0.4828 - val_accuracy: 0.8180
# Epoch 15/150
#  - 0s - loss: 0.4831 - accuracy: 0.7980 - val_loss: 0.4886 - val_accuracy: 0.8120
# Epoch 16/150
#  - 0s - loss: 0.4458 - accuracy: 0.8080 - val_loss: 0.4348 - val_accuracy: 0.8220
# Epoch 17/150
#  - 0s - loss: 0.4564 - accuracy: 0.8060 - val_loss: 0.4253 - val_accuracy: 0.8260
# Epoch 18/150
#  - 0s - loss: 0.4619 - accuracy: 0.8140 - val_loss: 0.4258 - val_accuracy: 0.8320
# Epoch 19/150
#  - 0s - loss: 0.4876 - accuracy: 0.7780 - val_loss: 0.4425 - val_accuracy: 0.8240
# Epoch 20/150
#  - 0s - loss: 0.4374 - accuracy: 0.8160 - val_loss: 0.4422 - val_accuracy: 0.8280
# Epoch 21/150
#  - 0s - loss: 0.4582 - accuracy: 0.8040 - val_loss: 0.4367 - val_accuracy: 0.8260
# Epoch 22/150
#  - 0s - loss: 0.4835 - accuracy: 0.7940 - val_loss: 0.4883 - val_accuracy: 0.8080
# Epoch 23/150
#  - 0s - loss: 0.5344 - accuracy: 0.7600 - val_loss: 0.4800 - val_accuracy: 0.8020
# Epoch 24/150
#  - 0s - loss: 0.4870 - accuracy: 0.7960 - val_loss: 0.4191 - val_accuracy: 0.8320
# Epoch 25/150
#  - 0s - loss: 0.4426 - accuracy: 0.8120 - val_loss: 0.4603 - val_accuracy: 0.8180
# Epoch 26/150
#  - 0s - loss: 0.5007 - accuracy: 0.7880 - val_loss: 0.4541 - val_accuracy: 0.8240
# Epoch 27/150
#  - 0s - loss: 0.4750 - accuracy: 0.7900 - val_loss: 0.4301 - val_accuracy: 0.8160
# Epoch 28/150
#  - 0s - loss: 0.4317 - accuracy: 0.8180 - val_loss: 0.4330 - val_accuracy: 0.8280
# Epoch 29/150
#  - 0s - loss: 0.4369 - accuracy: 0.8040 - val_loss: 0.4522 - val_accuracy: 0.8180
# Epoch 30/150
#  - 0s - loss: 0.4436 - accuracy: 0.8040 - val_loss: 0.4291 - val_accuracy: 0.8200
# Epoch 31/150
#  - 0s - loss: 0.4746 - accuracy: 0.7920 - val_loss: 0.4364 - val_accuracy: 0.8240
# Epoch 32/150
#  - 0s - loss: 0.4481 - accuracy: 0.8320 - val_loss: 0.4633 - val_accuracy: 0.8140
# Epoch 33/150
#  - 0s - loss: 0.4652 - accuracy: 0.7920 - val_loss: 0.4208 - val_accuracy: 0.8200
# Epoch 34/150
#  - 0s - loss: 0.4262 - accuracy: 0.8220 - val_loss: 0.4142 - val_accuracy: 0.8440
# Epoch 35/150
#  - 0s - loss: 0.4162 - accuracy: 0.8120 - val_loss: 0.4565 - val_accuracy: 0.8180
# Epoch 36/150
#  - 0s - loss: 0.4238 - accuracy: 0.8080 - val_loss: 0.4125 - val_accuracy: 0.8160
# Epoch 37/150
#  - 0s - loss: 0.4102 - accuracy: 0.8160 - val_loss: 0.4161 - val_accuracy: 0.8380
# Epoch 38/150
#  - 0s - loss: 0.4314 - accuracy: 0.8160 - val_loss: 0.4677 - val_accuracy: 0.8220
# Epoch 39/150
#  - 0s - loss: 0.4146 - accuracy: 0.8060 - val_loss: 0.4485 - val_accuracy: 0.8020
# Epoch 40/150
#  - 0s - loss: 0.4193 - accuracy: 0.8120 - val_loss: 0.4339 - val_accuracy: 0.8220
# Epoch 41/150
#  - 0s - loss: 0.4663 - accuracy: 0.8180 - val_loss: 0.4980 - val_accuracy: 0.7900
# Epoch 42/150
#  - 0s - loss: 0.4147 - accuracy: 0.8260 - val_loss: 0.4534 - val_accuracy: 0.8180
# Epoch 43/150
#  - 0s - loss: 0.4521 - accuracy: 0.8040 - val_loss: 0.5047 - val_accuracy: 0.8000
# Epoch 44/150
#  - 0s - loss: 0.4392 - accuracy: 0.8100 - val_loss: 0.4227 - val_accuracy: 0.8240
# Epoch 45/150
#  - 0s - loss: 0.4514 - accuracy: 0.8140 - val_loss: 0.4071 - val_accuracy: 0.8240
# Epoch 46/150
#  - 0s - loss: 0.3993 - accuracy: 0.8240 - val_loss: 0.4194 - val_accuracy: 0.8360
# Epoch 47/150
#  - 0s - loss: 0.4096 - accuracy: 0.8280 - val_loss: 0.4110 - val_accuracy: 0.8220
# Epoch 48/150
#  - 0s - loss: 0.4424 - accuracy: 0.8060 - val_loss: 0.4403 - val_accuracy: 0.8140
# Epoch 49/150
#  - 0s - loss: 0.4195 - accuracy: 0.8140 - val_loss: 0.4509 - val_accuracy: 0.8300
# Epoch 50/150
#  - 0s - loss: 0.4218 - accuracy: 0.8100 - val_loss: 0.5515 - val_accuracy: 0.7520
# Epoch 51/150
#  - 0s - loss: 0.4731 - accuracy: 0.7800 - val_loss: 0.4722 - val_accuracy: 0.7980
# Epoch 52/150
#  - 0s - loss: 0.4124 - accuracy: 0.8300 - val_loss: 0.4335 - val_accuracy: 0.8240
# Epoch 53/150
#  - 0s - loss: 0.4176 - accuracy: 0.8200 - val_loss: 0.4456 - val_accuracy: 0.8140
# Epoch 54/150
#  - 0s - loss: 0.4128 - accuracy: 0.8180 - val_loss: 0.4123 - val_accuracy: 0.8280
# Epoch 55/150
#  - 0s - loss: 0.4157 - accuracy: 0.8220 - val_loss: 0.4588 - val_accuracy: 0.8200
# Epoch 56/150
#  - 0s - loss: 0.4495 - accuracy: 0.8020 - val_loss: 0.4214 - val_accuracy: 0.8280
# Epoch 57/150
#  - 0s - loss: 0.4192 - accuracy: 0.8120 - val_loss: 0.5020 - val_accuracy: 0.8080
# Epoch 58/150
#  - 0s - loss: 0.4272 - accuracy: 0.8080 - val_loss: 0.4270 - val_accuracy: 0.8140
# Epoch 59/150
#  - 0s - loss: 0.4159 - accuracy: 0.8100 - val_loss: 0.4646 - val_accuracy: 0.8220
# Epoch 60/150
#  - 0s - loss: 0.4356 - accuracy: 0.8000 - val_loss: 0.4163 - val_accuracy: 0.8300
# Epoch 61/150
#  - 0s - loss: 0.4044 - accuracy: 0.8100 - val_loss: 0.4135 - val_accuracy: 0.8240
# Epoch 62/150
#  - 0s - loss: 0.4024 - accuracy: 0.8260 - val_loss: 0.4276 - val_accuracy: 0.8200
# Epoch 63/150
#  - 0s - loss: 0.4110 - accuracy: 0.8160 - val_loss: 0.4505 - val_accuracy: 0.8220
# Epoch 64/150
#  - 0s - loss: 0.4353 - accuracy: 0.8060 - val_loss: 0.5742 - val_accuracy: 0.7540
# Epoch 65/150
#  - 0s - loss: 0.4538 - accuracy: 0.8020 - val_loss: 0.4798 - val_accuracy: 0.8140
# Epoch 66/150
#  - 0s - loss: 0.4187 - accuracy: 0.8100 - val_loss: 0.4160 - val_accuracy: 0.8200
# Epoch 67/150
#  - 0s - loss: 0.4083 - accuracy: 0.8140 - val_loss: 0.4269 - val_accuracy: 0.8240
# Epoch 68/150
#  - 0s - loss: 0.3960 - accuracy: 0.8300 - val_loss: 0.4186 - val_accuracy: 0.8320
# Epoch 69/150
#  - 0s - loss: 0.3973 - accuracy: 0.8320 - val_loss: 0.4185 - val_accuracy: 0.8220
# Epoch 70/150
#  - 0s - loss: 0.4189 - accuracy: 0.8200 - val_loss: 0.4420 - val_accuracy: 0.8240
# Epoch 71/150
#  - 0s - loss: 0.4223 - accuracy: 0.8200 - val_loss: 0.4155 - val_accuracy: 0.8260
# Epoch 72/150
#  - 0s - loss: 0.4096 - accuracy: 0.8120 - val_loss: 0.4244 - val_accuracy: 0.8220
# Epoch 73/150
#  - 0s - loss: 0.4019 - accuracy: 0.8280 - val_loss: 0.4163 - val_accuracy: 0.8220
# Epoch 74/150
#  - 0s - loss: 0.4138 - accuracy: 0.8220 - val_loss: 0.4628 - val_accuracy: 0.8020
# Epoch 75/150
#  - 0s - loss: 0.4175 - accuracy: 0.8200 - val_loss: 0.4285 - val_accuracy: 0.8200
# Epoch 76/150
#  - 0s - loss: 0.4045 - accuracy: 0.8300 - val_loss: 0.4397 - val_accuracy: 0.8240
# Epoch 77/150
#  - 0s - loss: 0.4051 - accuracy: 0.8160 - val_loss: 0.4763 - val_accuracy: 0.8000
# Epoch 78/150
#  - 0s - loss: 0.4400 - accuracy: 0.8180 - val_loss: 0.4287 - val_accuracy: 0.8220
# Epoch 79/150
#  - 0s - loss: 0.4360 - accuracy: 0.8000 - val_loss: 0.4326 - val_accuracy: 0.8260
# Epoch 80/150
#  - 0s - loss: 0.4484 - accuracy: 0.7920 - val_loss: 0.4411 - val_accuracy: 0.8140
# Epoch 81/150
#  - 0s - loss: 0.4197 - accuracy: 0.8080 - val_loss: 0.4298 - val_accuracy: 0.8280
# Epoch 82/150
#  - 0s - loss: 0.4079 - accuracy: 0.8180 - val_loss: 0.4197 - val_accuracy: 0.8300
# Epoch 83/150
#  - 0s - loss: 0.4051 - accuracy: 0.8140 - val_loss: 0.4151 - val_accuracy: 0.8400
# Epoch 84/150
#  - 0s - loss: 0.4055 - accuracy: 0.8140 - val_loss: 0.4137 - val_accuracy: 0.8360
# Epoch 85/150
#  - 0s - loss: 0.4094 - accuracy: 0.8300 - val_loss: 0.4226 - val_accuracy: 0.8240
# Epoch 86/150
#  - 0s - loss: 0.3967 - accuracy: 0.8300 - val_loss: 0.4220 - val_accuracy: 0.8280
# Epoch 87/150
#  - 0s - loss: 0.4048 - accuracy: 0.8240 - val_loss: 0.4225 - val_accuracy: 0.8200
# Epoch 88/150
#  - 0s - loss: 0.4003 - accuracy: 0.8300 - val_loss: 0.4364 - val_accuracy: 0.8200
# Epoch 89/150
#  - 0s - loss: 0.3972 - accuracy: 0.8320 - val_loss: 0.4223 - val_accuracy: 0.8320
# Epoch 90/150
#  - 0s - loss: 0.4197 - accuracy: 0.8100 - val_loss: 0.4252 - val_accuracy: 0.8280
# Epoch 91/150
#  - 0s - loss: 0.4068 - accuracy: 0.8320 - val_loss: 0.4259 - val_accuracy: 0.8240
# Epoch 92/150
#  - 0s - loss: 0.4027 - accuracy: 0.8340 - val_loss: 0.4532 - val_accuracy: 0.8200
# Epoch 93/150
#  - 0s - loss: 0.4153 - accuracy: 0.8180 - val_loss: 0.4488 - val_accuracy: 0.8220
# Epoch 94/150
#  - 0s - loss: 0.4388 - accuracy: 0.8120 - val_loss: 0.4148 - val_accuracy: 0.8340
# Epoch 95/150
#  - 0s - loss: 0.4080 - accuracy: 0.8240 - val_loss: 0.4255 - val_accuracy: 0.8260
# Epoch 96/150
#  - 0s - loss: 0.3951 - accuracy: 0.8300 - val_loss: 0.4303 - val_accuracy: 0.8220
# Epoch 97/150
#  - 0s - loss: 0.3960 - accuracy: 0.8220 - val_loss: 0.4397 - val_accuracy: 0.8260
# Epoch 98/150
#  - 0s - loss: 0.4036 - accuracy: 0.8240 - val_loss: 0.4198 - val_accuracy: 0.8320
# Epoch 99/150
#  - 0s - loss: 0.4085 - accuracy: 0.8200 - val_loss: 0.4263 - val_accuracy: 0.8300
# Epoch 100/150
#  - 0s - loss: 0.4092 - accuracy: 0.8160 - val_loss: 0.4228 - val_accuracy: 0.8180
# Epoch 101/150
#  - 0s - loss: 0.4087 - accuracy: 0.8240 - val_loss: 0.4353 - val_accuracy: 0.8240
# Epoch 102/150
#  - 0s - loss: 0.4236 - accuracy: 0.8200 - val_loss: 0.4451 - val_accuracy: 0.8140
# Epoch 103/150
#  - 0s - loss: 0.4344 - accuracy: 0.8140 - val_loss: 0.4981 - val_accuracy: 0.8060
# Epoch 104/150
#  - 0s - loss: 0.4133 - accuracy: 0.8220 - val_loss: 0.4305 - val_accuracy: 0.8300
# Epoch 105/150
#  - 0s - loss: 0.4089 - accuracy: 0.8260 - val_loss: 0.4210 - val_accuracy: 0.8240
# Epoch 106/150
#  - 0s - loss: 0.4102 - accuracy: 0.8160 - val_loss: 0.4380 - val_accuracy: 0.8220
# Epoch 107/150
#  - 0s - loss: 0.4191 - accuracy: 0.8200 - val_loss: 0.4230 - val_accuracy: 0.8240
# Epoch 108/150
#  - 0s - loss: 0.4085 - accuracy: 0.8300 - val_loss: 0.4310 - val_accuracy: 0.8260
# Epoch 109/150
#  - 0s - loss: 0.3950 - accuracy: 0.8260 - val_loss: 0.4278 - val_accuracy: 0.8240
# Epoch 110/150
#  - 0s - loss: 0.4102 - accuracy: 0.8180 - val_loss: 0.4286 - val_accuracy: 0.8340
# Epoch 111/150
#  - 0s - loss: 0.3942 - accuracy: 0.8320 - val_loss: 0.4192 - val_accuracy: 0.8180
# Epoch 112/150
#  - 0s - loss: 0.3967 - accuracy: 0.8200 - val_loss: 0.4297 - val_accuracy: 0.8240
# Epoch 113/150
#  - 0s - loss: 0.4101 - accuracy: 0.8340 - val_loss: 0.4441 - val_accuracy: 0.8180
# Epoch 114/150
#  - 0s - loss: 0.3995 - accuracy: 0.8240 - val_loss: 0.4337 - val_accuracy: 0.8240
# Epoch 115/150
#  - 0s - loss: 0.4181 - accuracy: 0.8260 - val_loss: 0.4299 - val_accuracy: 0.8320
# Epoch 116/150
#  - 0s - loss: 0.4362 - accuracy: 0.8000 - val_loss: 0.4449 - val_accuracy: 0.8180
# Epoch 117/150
#  - 0s - loss: 0.4053 - accuracy: 0.8280 - val_loss: 0.4236 - val_accuracy: 0.8240
# Epoch 118/150
#  - 0s - loss: 0.4159 - accuracy: 0.8080 - val_loss: 0.4161 - val_accuracy: 0.8300
# Epoch 119/150
#  - 0s - loss: 0.3977 - accuracy: 0.8120 - val_loss: 0.4551 - val_accuracy: 0.8200
# Epoch 120/150
#  - 0s - loss: 0.4043 - accuracy: 0.8180 - val_loss: 0.4253 - val_accuracy: 0.8180
# Epoch 121/150
#  - 0s - loss: 0.3938 - accuracy: 0.8280 - val_loss: 0.4344 - val_accuracy: 0.8280
# Epoch 122/150
#  - 0s - loss: 0.4001 - accuracy: 0.8180 - val_loss: 0.4280 - val_accuracy: 0.8240
# Epoch 123/150
#  - 0s - loss: 0.3963 - accuracy: 0.8200 - val_loss: 0.4491 - val_accuracy: 0.8120
# Epoch 124/150
#  - 0s - loss: 0.4069 - accuracy: 0.8160 - val_loss: 0.4254 - val_accuracy: 0.8200
# Epoch 125/150
#  - 0s - loss: 0.3901 - accuracy: 0.8200 - val_loss: 0.4323 - val_accuracy: 0.8200
# Epoch 126/150
#  - 0s - loss: 0.4231 - accuracy: 0.8240 - val_loss: 0.4833 - val_accuracy: 0.8020
# Epoch 127/150
#  - 0s - loss: 0.4145 - accuracy: 0.8180 - val_loss: 0.4213 - val_accuracy: 0.8200
# Epoch 128/150
#  - 0s - loss: 0.3927 - accuracy: 0.8260 - val_loss: 0.4559 - val_accuracy: 0.8040
# Epoch 129/150
#  - 0s - loss: 0.4170 - accuracy: 0.8060 - val_loss: 0.4681 - val_accuracy: 0.8060
# Epoch 130/150
#  - 0s - loss: 0.3974 - accuracy: 0.8140 - val_loss: 0.4349 - val_accuracy: 0.8180
# Epoch 131/150
#  - 0s - loss: 0.3958 - accuracy: 0.8360 - val_loss: 0.4497 - val_accuracy: 0.8200
# Epoch 132/150
#  - 0s - loss: 0.4036 - accuracy: 0.8120 - val_loss: 0.4268 - val_accuracy: 0.8220
# Epoch 133/150
#  - 0s - loss: 0.3965 - accuracy: 0.8360 - val_loss: 0.4271 - val_accuracy: 0.8220
# Epoch 134/150
#  - 0s - loss: 0.3960 - accuracy: 0.8260 - val_loss: 0.4240 - val_accuracy: 0.8200
# Epoch 135/150
#  - 0s - loss: 0.3939 - accuracy: 0.8260 - val_loss: 0.4306 - val_accuracy: 0.8220
# Epoch 136/150
#  - 0s - loss: 0.3927 - accuracy: 0.8240 - val_loss: 0.4571 - val_accuracy: 0.8100
# Epoch 137/150
#  - 0s - loss: 0.4109 - accuracy: 0.8200 - val_loss: 0.4431 - val_accuracy: 0.8160
# Epoch 138/150
#  - 0s - loss: 0.4218 - accuracy: 0.8040 - val_loss: 0.4510 - val_accuracy: 0.8100
# Epoch 139/150
#  - 0s - loss: 0.4113 - accuracy: 0.8220 - val_loss: 0.4276 - val_accuracy: 0.8300
# Epoch 140/150
#  - 0s - loss: 0.4063 - accuracy: 0.8240 - val_loss: 0.4240 - val_accuracy: 0.8280
# Epoch 141/150
#  - 0s - loss: 0.4160 - accuracy: 0.8220 - val_loss: 0.4252 - val_accuracy: 0.8220
# Epoch 142/150
#  - 0s - loss: 0.3971 - accuracy: 0.8220 - val_loss: 0.4549 - val_accuracy: 0.8160
# Epoch 143/150
#  - 0s - loss: 0.3970 - accuracy: 0.8140 - val_loss: 0.4588 - val_accuracy: 0.8180
# Epoch 144/150
#  - 0s - loss: 0.4096 - accuracy: 0.8080 - val_loss: 0.4781 - val_accuracy: 0.8000
# Epoch 145/150
#  - 0s - loss: 0.4269 - accuracy: 0.8020 - val_loss: 0.5589 - val_accuracy: 0.7560
# Epoch 146/150
#  - 0s - loss: 0.4262 - accuracy: 0.7960 - val_loss: 0.4182 - val_accuracy: 0.8200
# Epoch 147/150
#  - 0s - loss: 0.3849 - accuracy: 0.8300 - val_loss: 0.4286 - val_accuracy: 0.8180
# Epoch 148/150
#  - 0s - loss: 0.3955 - accuracy: 0.8200 - val_loss: 0.4841 - val_accuracy: 0.7920
# Epoch 149/150
#  - 0s - loss: 0.4049 - accuracy: 0.8180 - val_loss: 0.4251 - val_accuracy: 0.8220
# Epoch 150/150
#  - 0s - loss: 0.3876 - accuracy: 0.8260 - val_loss: 0.4311 - val_accuracy: 0.8220
# accuracy =  0.826   validation loss =  0.431
# CPU times: user 5.61 s, sys: 321 ms, total: 5.94 s
# Wall time: 5.39 s

# %% [markdown]
# Q7 . RNN 문장 생성기

# %%
# 다음의 코드를 완성하시오
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import numpy as np
from tensorflow.keras.utils import to_categorical

text="""특히 최근 수도권에서는 교회 소모임 참석자에 이어 이들 가족과 지인으로 번지는 2차 감염 사례가 증가하고 있습니다. 중앙재난안전대책본부는 오늘까지 수도권 교회와 관련한 코로나19 확진자는 총 63명이라고 밝혔으며  2차 감염자는 33명 이라고 전했습니다. """


t = Tokenizer()
t.fit_on_texts([text])
vocab_size = len(t.word_index) + 1
print('단어 집합의 크기 : %d' % vocab_size)


print(t.word_index)

sequences = list()
for line in text.split('\n'): 
    encoded = t.texts_to_sequences([line])[0]
    for i in range(1, len(encoded)):
        sequence = encoded[:i+1]
        sequences.append(sequence)

print('학습에 사용할 샘플의 개수: %d' % len(sequences))


max_len=max(len(l) for l in sequences) 

sequences = pad_sequences(sequences, maxlen=max_len, padding='pre')

sequences = np.array(sequences)
X = sequences[:,:-1]
y = sequences[:,-1]


from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding, Dense, SimpleRNN

model = Sequential()
model.add(Embedding(vocab_size, 10, input_length=max_len-1))  
model.add(SimpleRNN(32))
model.add(Dense(vocab_size, activation='softmax'))
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
model.fit(X, y, epochs=120, verbose=2)

# 이 블록에서 yoou_code_here 부분을 완성하시오
def sentence_generation(model, t, current_word, n): # model = 모델, t = 토크나이저, current_word = 현재 단어, n = 반복할 횟수
    init_word = current_word # 처음 들어온 단어도 마지막에 같이 출력하기위해 저장
    sentence = ''
    for _ in range(n): # n번 반복
        encoded = t.texts_to_sequences([current_word])[0] # 현재 단어에 대한 정수 인코딩
        encoded = pad_sequences([encoded], maxlen=30, padding='pre') # 데이터에 대한 패딩
        result = np.argmax(model.predict(encoded), axis=-1)
        for word, index in t.word_index.items(): 
            if index == result: # 만약 예측한 단어의 인덱스 값이 동일한 단어가 있다면
                break # 해당 단어가 예측 단어이므로 break
        current_word = result # 현재 단어 + ' ' + 예측한 단어를 current_word로 저장
        sentence = np.append(sentence,current_word)  # 예측한 단어를 sentence에 append
     
    sentence = np.concatenate(model, sentence) # 초기의 텍스트와 for loop에서 생성된 텍스트를 concatenate
    return sentence

print(sentence_generation(model, t, '특히', 10))
# Out:
# 단어 집합의 크기 : 31
# {'2차': 1, '특히': 2, '최근': 3, '수도권에서는': 4, '교회': 5, '소모임': 6, '참석자에': 7, '이어': 8, '이들': 9, '가족과': 10, '지인으로': 11, '번지는': 12, '감염': 13, '사례가': 14, '증가하고': 15, '있습니다': 16, '중앙재난안전대책본부는': 17, '오늘까지': 18, '수도권': 19, '교회와': 20, '관련한': 21, '코로나19': 22, '확진자는': 23, '총': 24, '63명이라고': 25, '밝혔으며': 26, '감염자는': 27, '33명': 28, '이라고': 29, '전했습니다': 30}
# 학습에 사용할 샘플의 개수: 30
# Epoch 1/120
# 1/1 - 0s - loss: 3.4396 - accuracy: 0.0000e+00
# Epoch 2/120
# 1/1 - 0s - loss: 3.4229 - accuracy: 0.0000e+00
# Epoch 3/120
# 1/1 - 0s - loss: 3.4071 - accuracy: 0.0000e+00
# Epoch 4/120
# 1/1 - 0s - loss: 3.3911 - accuracy: 0.0333
# Epoch 5/120
# 1/1 - 0s - loss: 3.3742 - accuracy: 0.0667
# Epoch 6/120
# 1/1 - 0s - loss: 3.3564 - accuracy: 0.0667
# Epoch 7/120
# 1/1 - 0s - loss: 3.3376 - accuracy: 0.1000
# Epoch 8/120
# 1/1 - 0s - loss: 3.3179 - accuracy: 0.1333
# Epoch 9/120
# 1/1 - 0s - loss: 3.2974 - accuracy: 0.1667
# Epoch 10/120
# 1/1 - 0s - loss: 3.2762 - accuracy: 0.1667
# Epoch 11/120
# 1/1 - 0s - loss: 3.2545 - accuracy: 0.1667
# Epoch 12/120
# 1/1 - 0s - loss: 3.2326 - accuracy: 0.2000
# Epoch 13/120
# 1/1 - 0s - loss: 3.2108 - accuracy: 0.2000
# Epoch 14/120
# 1/1 - 0s - loss: 3.1890 - accuracy: 0.2000
# Epoch 15/120
# 1/1 - 0s - loss: 3.1670 - accuracy: 0.2000
# Epoch 16/120
# 1/1 - 0s - loss: 3.1448 - accuracy: 0.2667
# Epoch 17/120
# 1/1 - 0s - loss: 3.1220 - accuracy: 0.2667
# Epoch 18/120
# 1/1 - 0s - loss: 3.0987 - accuracy: 0.2667
# Epoch 19/120
# 1/1 - 0s - loss: 3.0749 - accuracy: 0.3333
# Epoch 20/120
# 1/1 - 0s - loss: 3.0509 - accuracy: 0.3000
# Epoch 21/120
# 1/1 - 0s - loss: 3.0269 - accuracy: 0.3000
# Epoch 22/120
# 1/1 - 0s - loss: 3.0027 - accuracy: 0.3000
# Epoch 23/120
# 1/1 - 0s - loss: 2.9780 - accuracy: 0.3000
# Epoch 24/120
# 1/1 - 0s - loss: 2.9527 - accuracy: 0.3333
# Epoch 25/120
# 1/1 - 0s - loss: 2.9278 - accuracy: 0.3333
# Epoch 26/120
# 1/1 - 0s - loss: 2.9039 - accuracy: 0.3333
# Epoch 27/120
# 1/1 - 0s - loss: 2.8807 - accuracy: 0.3333
# Epoch 28/120
# 1/1 - 0s - loss: 2.8567 - accuracy: 0.3333
# Epoch 29/120
# 1/1 - 0s - loss: 2.8315 - accuracy: 0.3667
# Epoch 30/120
# 1/1 - 0s - loss: 2.8064 - accuracy: 0.3667
# Epoch 31/120
# 1/1 - 0s - loss: 2.7814 - accuracy: 0.3667
# Epoch 32/120
# 1/1 - 0s - loss: 2.7561 - accuracy: 0.3667
# Epoch 33/120
# 1/1 - 0s - loss: 2.7308 - accuracy: 0.4000
# Epoch 34/120
# 1/1 - 0s - loss: 2.7064 - accuracy: 0.4000
# Epoch 35/120
# 1/1 - 0s - loss: 2.6804 - accuracy: 0.4667
# Epoch 36/120
# 1/1 - 0s - loss: 2.6556 - accuracy: 0.5000
# Epoch 37/120
# 1/1 - 0s - loss: 2.6292 - accuracy: 0.5000
# Epoch 38/120
# 1/1 - 0s - loss: 2.6042 - accuracy: 0.5000
# Epoch 39/120
# 1/1 - 0s - loss: 2.5775 - accuracy: 0.5000
# Epoch 40/120
# 1/1 - 0s - loss: 2.5523 - accuracy: 0.5000
# Epoch 41/120
# 1/1 - 0s - loss: 2.5258 - accuracy: 0.5333
# Epoch 42/120
# 1/1 - 0s - loss: 2.5005 - accuracy: 0.5333
# Epoch 43/120
# 1/1 - 0s - loss: 2.4743 - accuracy: 0.5000
# Epoch 44/120
# 1/1 - 0s - loss: 2.4483 - accuracy: 0.5000
# Epoch 45/120
# 1/1 - 0s - loss: 2.4275 - accuracy: 0.5000
# Epoch 46/120
# 1/1 - 0s - loss: 2.4042 - accuracy: 0.5000
# Epoch 47/120
# 1/1 - 0s - loss: 2.3729 - accuracy: 0.5000
# Epoch 48/120
# 1/1 - 0s - loss: 2.3497 - accuracy: 0.5000
# Epoch 49/120
# 1/1 - 0s - loss: 2.3236 - accuracy: 0.5000
# Epoch 50/120
# 1/1 - 0s - loss: 2.2991 - accuracy: 0.5333
# Epoch 51/120
# 1/1 - 0s - loss: 2.2743 - accuracy: 0.5667
# Epoch 52/120
# 1/1 - 0s - loss: 2.2484 - accuracy: 0.5667
# Epoch 53/120
# 1/1 - 0s - loss: 2.2246 - accuracy: 0.6000
# Epoch 54/120
# 1/1 - 0s - loss: 2.1997 - accuracy: 0.6000
# Epoch 55/120
# 1/1 - 0s - loss: 2.1748 - accuracy: 0.6000
# Epoch 56/120
# 1/1 - 0s - loss: 2.1502 - accuracy: 0.6333
# Epoch 57/120
# 1/1 - 0s - loss: 2.1263 - accuracy: 0.6667
# Epoch 58/120
# 1/1 - 0s - loss: 2.1013 - accuracy: 0.6667
# Epoch 59/120
# 1/1 - 0s - loss: 2.0778 - accuracy: 0.7000
# Epoch 60/120
# 1/1 - 0s - loss: 2.0524 - accuracy: 0.6667
# Epoch 61/120
# 1/1 - 0s - loss: 2.0294 - accuracy: 0.7000
# Epoch 62/120
# 1/1 - 0s - loss: 2.0044 - accuracy: 0.7667
# Epoch 63/120
# 1/1 - 0s - loss: 1.9815 - accuracy: 0.7333
# Epoch 64/120
# 1/1 - 0s - loss: 1.9571 - accuracy: 0.8000
# Epoch 65/120
# 1/1 - 0s - loss: 1.9342 - accuracy: 0.8000
# Epoch 66/120
# 1/1 - 0s - loss: 1.9103 - accuracy: 0.8000
# Epoch 67/120
# 1/1 - 0s - loss: 1.8860 - accuracy: 0.8000
# Epoch 68/120
# 1/1 - 0s - loss: 1.8642 - accuracy: 0.8000
# Epoch 69/120
# 1/1 - 0s - loss: 1.8431 - accuracy: 0.8333
# Epoch 70/120
# 1/1 - 0s - loss: 1.8223 - accuracy: 0.8333
# Epoch 71/120
# 1/1 - 0s - loss: 1.7996 - accuracy: 0.8333
# Epoch 72/120
# 1/1 - 0s - loss: 1.7741 - accuracy: 0.8333
# Epoch 73/120
# 1/1 - 0s - loss: 1.7524 - accuracy: 0.8333
# Epoch 74/120
# 1/1 - 0s - loss: 1.7326 - accuracy: 0.8333
# Epoch 75/120
# 1/1 - 0s - loss: 1.7084 - accuracy: 0.8333
# Epoch 76/120
# 1/1 - 0s - loss: 1.6868 - accuracy: 0.8333
# Epoch 77/120
# 1/1 - 0s - loss: 1.6680 - accuracy: 0.8333
# Epoch 78/120
# 1/1 - 0s - loss: 1.6457 - accuracy: 0.8333
# Epoch 79/120
# 1/1 - 0s - loss: 1.6238 - accuracy: 0.8333
# Epoch 80/120
# 1/1 - 0s - loss: 1.6032 - accuracy: 0.8333
# Epoch 81/120
# 1/1 - 0s - loss: 1.5840 - accuracy: 0.8333
# Epoch 82/120
# 1/1 - 0s - loss: 1.5648 - accuracy: 0.8667
# Epoch 83/120
# 1/1 - 0s - loss: 1.5430 - accuracy: 0.8667
# Epoch 84/120
# 1/1 - 0s - loss: 1.5244 - accuracy: 0.8667
# Epoch 85/120
# 1/1 - 0s - loss: 1.5061 - accuracy: 0.8667
# Epoch 86/120
# 1/1 - 0s - loss: 1.4865 - accuracy: 0.8667
# Epoch 87/120
# 1/1 - 0s - loss: 1.4654 - accuracy: 0.8667
# Epoch 88/120
# 1/1 - 0s - loss: 1.4485 - accuracy: 0.8667
# Epoch 89/120
# 1/1 - 0s - loss: 1.4326 - accuracy: 0.8667
# Epoch 90/120
# 1/1 - 0s - loss: 1.4107 - accuracy: 0.8667
# Epoch 91/120
# 1/1 - 0s - loss: 1.3929 - accuracy: 0.8667
# Epoch 92/120
# 1/1 - 0s - loss: 1.3803 - accuracy: 0.8667
# Epoch 93/120
# 1/1 - 0s - loss: 1.3569 - accuracy: 0.8667
# Epoch 94/120
# 1/1 - 0s - loss: 1.3422 - accuracy: 0.9333
# Epoch 95/120
# 1/1 - 0s - loss: 1.3257 - accuracy: 0.8667
# Epoch 96/120
# 1/1 - 0s - loss: 1.3084 - accuracy: 0.8667
# Epoch 97/120
# 1/1 - 0s - loss: 1.2967 - accuracy: 0.9333
# Epoch 98/120
# 1/1 - 0s - loss: 1.2748 - accuracy: 0.9000
# Epoch 99/120
# 1/1 - 0s - loss: 1.2708 - accuracy: 0.8667
# Epoch 100/120
# 1/1 - 0s - loss: 1.2611 - accuracy: 0.9000
# Epoch 101/120
# 1/1 - 0s - loss: 1.2479 - accuracy: 0.9333
# Epoch 102/120
# 1/1 - 0s - loss: 1.2205 - accuracy: 0.9333
# Epoch 103/120
# 1/1 - 0s - loss: 1.2066 - accuracy: 0.9000
# Epoch 104/120
# 1/1 - 0s - loss: 1.1975 - accuracy: 0.8667
# Epoch 105/120
# 1/1 - 0s - loss: 1.1782 - accuracy: 0.9333
# Epoch 106/120
# 1/1 - 0s - loss: 1.1581 - accuracy: 0.9667
# Epoch 107/120
# 1/1 - 0s - loss: 1.1479 - accuracy: 0.9667
# Epoch 108/120
# 1/1 - 0s - loss: 1.1320 - accuracy: 0.9667
# Epoch 109/120
# 1/1 - 0s - loss: 1.1189 - accuracy: 0.9667
# Epoch 110/120
# 1/1 - 0s - loss: 1.1004 - accuracy: 0.9667
# Epoch 111/120
# 1/1 - 0s - loss: 1.0944 - accuracy: 0.9667
# Epoch 112/120
# 1/1 - 0s - loss: 1.0741 - accuracy: 0.9667
# Epoch 113/120
# 1/1 - 0s - loss: 1.0646 - accuracy: 0.9667
# Epoch 114/120
# 1/1 - 0s - loss: 1.0481 - accuracy: 0.9667
# Epoch 115/120
# 1/1 - 0s - loss: 1.0384 - accuracy: 0.9667
# Epoch 116/120
# 1/1 - 0s - loss: 1.0234 - accuracy: 0.9667
# Epoch 117/120
# 1/1 - 0s - loss: 1.0107 - accuracy: 0.9667
# Epoch 118/120
# 1/1 - 0s - loss: 0.9997 - accuracy: 0.9667
# Epoch 119/120
# 1/1 - 0s - loss: 0.9858 - accuracy: 0.9667
# Epoch 120/120
# 1/1 - 0s - loss: 0.9752 - accuracy: 0.9667
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-42-d2bbc4c820b7> in <module>()
#      62     return sentence
#      63
# ---> 64 print(sentence_generation(model, t, '특히', 10))
#
# <ipython-input-42-d2bbc4c820b7> in sentence_generation(model, t, current_word, n)
#      50     sentence = ''
#      51     for _ in range(n): # n번 반복
# ---> 52         encoded = t.texts_to_sequences([current_word])[0] # 현재 단어에 대한 정수 인코딩
#      53         encoded = pad_sequences([encoded], maxlen=30, padding='pre') # 데이터에 대한 패딩
#      54         result = np.argmax(model.predict(encoded), axis=-1)
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/text.py in texts_to_sequences(self, texts)
#     279             A list of sequences.
#     280         """
# --> 281         return list(self.texts_to_sequences_generator(texts))
#     282
#     283     def texts_to_sequences_generator(self, texts):
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/text.py in texts_to_sequences_generator(self, texts)
#     310                                             self.filters,
#     311                                             self.lower,
# --> 312                                             self.split)
#     313             vect = []
#     314             for w in seq:
#
# /usr/local/lib/python3.6/dist-packages/keras_preprocessing/text.py in text_to_word_sequence(text, filters, lower, split)
#      41     """
#      42     if lower:
# ---> 43         text = text.lower()
#      44
#      45     if sys.version_info < (3,):
#
# AttributeError: 'numpy.ndarray' object has no attribute 'lower'

# %% [markdown]
# ## 20년1학기-기말고사-yourname.ipynb로 다운로드한 후 제출하십시오.
# 수고하였습니다!
